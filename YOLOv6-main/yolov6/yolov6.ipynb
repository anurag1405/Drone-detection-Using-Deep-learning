# %%
cd C:\Users\anura\Documents\YOLOv6-main
# Out:
# C:\Users\anura\Documents\YOLOv6-main

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# !python tools/infer.py --weights yolov6.pt --source "C:\Users\anura\OneDrive\Desktop\train\train\images\train\frame_0052.jpg"
img = mpimg.imread(r"C:\Users\anura\Documents\YOLOv6-main\runs\inference\exp\frame_0052.jpg")
plt.imshow(img)
plt.show()
# Out:
# Namespace(weights='yolov6.pt', source='C:\\Users\\anura\\OneDrive\\Desktop\\train\\train\\images\\train\\frame_0052.jpg', webcam=False, webcam_addr='0', yaml='data/coco.yaml', img_size=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device='0', save_txt=False, not_save_img=False, save_dir=None, view_img=False, classes=None, agnostic_nms=False, project='runs/inference', name='exp', hide_labels=False, hide_conf=False, half=False)
# Save directory already existed
# Loading checkpoint from yolov6.pt
#
# Fusing model...
# Switch model to deploy modality.
# c:\Users\anura\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ..\aten\src\ATen\native\TensorShape.cpp:2895.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# ...
# 100%|██████████| 1/1 [00:00<00:00,  7.76it/s]
# ...

# %%
import cv2
# !python tools/infer.py --weights yolov6.pt --source "C:\Users\anura\Downloads\Drone-detection-dataset-v1.0.0\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\Data\Video_V\V_DRONE_001.mp4"
cap = cv2.VideoCapture(r"C:\Users\anura\Documents\YOLOv6-main\runs\inference\exp\V_DRONE_001.mp4")
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
        cv2.imshow('frame',frame)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Namespace(weights='yolov6.pt', source='C:\\Users\\anura\\Downloads\\Drone-detection-dataset-v1.0.0\\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\\Data\\Video_V\\V_DRONE_001.mp4', webcam=False, webcam_addr='0', yaml='data/coco.yaml', img_size=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device='0', save_txt=False, not_save_img=False, save_dir=None, view_img=False, classes=None, agnostic_nms=False, project='runs/inference', name='exp', hide_labels=False, hide_conf=False, half=False)
# Save directory already existed
# Loading checkpoint from yolov6.pt
#
# Fusing model...
# Switch model to deploy modality.
# c:\Users\anura\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ..\aten\src\ATen\native\TensorShape.cpp:2895.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# ...
