# %%
cd C0-542:\Users\anura\Downloads\yolov5-master
# Out:
# C:\Users\anura\Downloads\yolov5-master

# %%
# !python val.py --weights yolov5.pt --data coco128.yaml --img 640
# Out:
# requirements: C:\Users\anura\Downloads\requirements.txt not found, check failed.
# val: data=C:\Users\anura\Downloads\yolov5-master\data\coco128.yaml, weights=['yolov5.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  2023-5-2 Python-3.10.1 torch-1.13.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#
# val: Scanning C:\Users\anura\Downloads\yolov5-master\data\train\labels\val.cache... 273 images, 0 backgrounds, 0 corrupt: 100%|██████████| 273/273 [00:00<?, ?it/s]
# val: Scanning C:\Users\anura\Downloads\yolov5-master\data\train\labels\val.cache... 273 images, 0 backgrounds, 0 corrupt: 100%|██████████| 273/273 [00:00<?, ?it/s]
#
# ...

# %%
# Out:
# ...
#   Using cached yolov5-7.0.11-py37.py38.py39.py310-none-any.whl (956 kB)
# ...
#   Using cached sahi-0.11.13-py3-none-any.whl (100 kB)
# ...
#   Using cached fire-0.5.0.tar.gz (88 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 56.2/56.2 kB 112.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 224.5/224.5 kB 107.1 kB/s eta 0:00:00
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# ...
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# ...
#   Using cached wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# ...
#      -------------------------------------- 54.5/54.5 kB 941.3 kB/s eta 0:00:00
# ...
