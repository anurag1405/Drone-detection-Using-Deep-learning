# %%
cd "C:\Users\anura\Downloads\yolov5-master"
# Out:
# C:\Users\anura\Downloads\yolov5-master

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# !python detect.py --weights yolov5.pt --img 640 --conf 0.25 --source "C:\Users\anura\OneDrive\Desktop\train\train\images\train\frame_0052.jpg"
img = mpimg.imread(r"C:\Users\anura\Downloads\yolov5-master\runs\detect\exp8\frame_0052.jpg")
plt.imshow(img)
plt.show()
# Out:
# requirements: C:\Users\anura\Downloads\requirements.txt not found, check failed.
# detect: weights=['yolov5.pt'], source=C:\Users\anura\OneDrive\Desktop\train\train\images\train\frame_0052.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2023-5-2 Python-3.10.1 torch-1.12.1+cu113 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 C:\Users\anura\OneDrive\Desktop\train\train\images\train\frame_0052.jpg: 512x640 1 drone, 18.2ms
# Speed: 3.1ms pre-process, 18.2ms inference, 75.1ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
import cv2
# !python detect.py --weights yolov5.pt --img 640 --conf 0.25 --source "C:\Users\anura\Downloads\Drone-detection-dataset-v1.0.0\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\Data\Video_V\V_DRONE_001.mp4"
cap = cv2.VideoCapture(r"C:\Users\anura\Downloads\yolov5-master\runs\detect\exp9\V_DRONE_001.mp4")
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
        cv2.imshow('frame',frame)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# detect: weights=['yolov5.pt'], source=C:\Users\anura\Downloads\Drone-detection-dataset-v1.0.0\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\Data\Video_V\V_DRONE_001.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  2023-5-2 Python-3.10.1 torch-1.12.1+cu113 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/301) C:\Users\anura\Downloads\Drone-detection-dataset-v1.0.0\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\Data\Video_V\V_DRONE_001.mp4: 512x640 1 drone, 17.0ms
# ...
