# %%
cd C:\Users\anura\Documents\ultralytics-main
# Out:
# C:\Users\anura\Documents\ultralytics-main

# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'c:\Users\anura\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# !yolo predict model=yolov8.pt source="C:\Users\anura\OneDrive\Desktop\train\train\images\train\frame_0052.jpg"
img = mpimg.imread(r"C:\Users\anura\Documents\ultralytics-main\runs\detect\predict4\frame_0052.jpg")
plt.imshow(img)
plt.show()
# Out:
# Ultralytics YOLOv8.0.92  Python-3.10.1 torch-1.12.1+cu113 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 C:\Users\anura\OneDrive\Desktop\train\train\images\train\frame_0052.jpg: 512x640 1 drone, 38.8ms
# Speed: 8.5ms preprocess, 38.8ms inference, 67.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict4

# %%
import cv2
# !yolo predict model=yolov8.pt source="C:\Users\anura\Downloads\Drone-detection-dataset-v1.0.0\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\Data\Video_V\V_DRONE_001.mp4"
cap = cv2.VideoCapture(r"C:\Users\anura\Documents\ultralytics-main\runs\detect\predict5\V_DRONE_001.mp4")
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
        cv2.imshow('frame',frame)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
    else:
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Ultralytics YOLOv8.0.92  Python-3.10.1 torch-1.12.1+cu113 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/301) C:\Users\anura\Downloads\Drone-detection-dataset-v1.0.0\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\Data\Video_V\V_DRONE_001.mp4: 512x640 1 drone, 42.0ms
# video 1/1 (2/301) C:\Users\anura\Downloads\Drone-detection-dataset-v1.0.0\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\Data\Video_V\V_DRONE_001.mp4: 512x640 1 drone, 20.0ms
# video 1/1 (3/301) C:\Users\anura\Downloads\Drone-detection-dataset-v1.0.0\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\Data\Video_V\V_DRONE_001.mp4: 512x640 1 drone, 16.0ms
# video 1/1 (4/301) C:\Users\anura\Downloads\Drone-detection-dataset-v1.0.0\DroneDetectionThesis-Drone-detection-dataset-e7a6eaf\Data\Video_V\V_DRONE_001.mp4: 512x640 1 drone, 13.9ms
# ...
