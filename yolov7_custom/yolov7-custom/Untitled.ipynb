# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python train.py --workers 1 --device 0 --batch 2 --epochs 100 --img 640 640 --data data/coco.yaml --hyp data/hyp.scratch.custom.yaml --cfg "C:\Users\anura\Downloads\yolov7_custom\yolov7-custom\cfg\training\yolov7x _Custom.yaml" --weights yolov7.pt
# Out:
# wandb: Install Weights & Biases for YOLOR logging with 'pip install wandb' (recommended)
#
# autoanchor: Analyzing anchors... anchors/target = 4.90, Best Possible Recall (BPR) = 1.0000
# YOLOR  2023-4-20 torch 1.12.1 CUDA:0 (NVIDIA GeForce GTX 1650, 4095.6875MB)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4056\1434417243.py in <module>
# ----> 1 torch.cuda_memory_info()
#
# AttributeError: module 'torch' has no attribute 'cuda_memory_info'
